# %%
import matplotlib.pyplot as plt

x = empname = ['Shala', 'Mohammed', 'Nur', 'Rani']
y = salary = [2500, 3000, 2000, 4500]

plt.plot(x, y, marker = 'X', color = 'green')
#plt.bar(x, y, color = 'green')
plt.title('EMPLOYEES SALARY REPORT')
plt.xlabel('NAME')
plt.ylabel('SALARY (RM)')

plt.show()

# %%
import matplotlib.pyplot as plt

x = empname = ['Shala', 'Mohammed', 'Nur', 'Rani']
y = salary = [2500, 3000, 2000, 4500]

#plt.plot(x, y, marker = 'X', color = 'green')
plt.bar(x, y, color = 'green')
plt.title('EMPLOYEES SALARY REPORT')
plt.xlabel('NAME')
plt.ylabel('SALARY (RM)')

plt.show()

# %%
import matplotlib.pyplot as plt

x = empname = ['Shala', 'Mohammed', 'Nur', 'Rani']
y = salary = [2500, 3000, 2000, 4500]

#plt.plot(x, y, marker = 'X', color = 'green')
plt.pie(y, labels = x)
plt.title('EMPLOYEES SALARY REPORT')
plt.xlabel('NAME')
plt.ylabel('SALARY (RM)')

plt.show()

# %%
import matplotlib.pyplot as plt

x = empname = ['Shala', 'Mohammed', 'Nur', 'Rani']
y = salary = [2500, 3000, 2000, 4500]

#plt.plot(x, y, marker = 'X', color = 'green')
plt.scatter(x, y)
plt.title('EMPLOYEES SALARY REPORT')
plt.xlabel('NAME')
plt.ylabel('SALARY (RM)')

plt.show()
